# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the dataset
data = pd.read_csv("BankChurners_Cleaned.csv")

# %%
# Inspect data types
print("\nData Types:")
print(data.dtypes)

# Check the number of rows and columns
print("\nDataset Shape:")
print(data.shape)
# Out:
# Data Types:
# CLIENTNUM                                                                                                                               int64
# Attrition_Flag                                                                                                                         object
# Customer_Age                                                                                                                            int64
# Gender                                                                                                                                 object
# Dependent_count                                                                                                                         int64
# Education_Level                                                                                                                        object
# ...

# %%
# Inspect data types
print("\nData Types:")
print(data.dtypes)

# Check the number of rows and columns
print("\nDataset Shape:")
print(data.shape)
# Out:
# Data Types:
# CLIENTNUM                                                                                                                               int64
# Attrition_Flag                                                                                                                         object
# Customer_Age                                                                                                                            int64
# Gender                                                                                                                                 object
# Dependent_count                                                                                                                         int64
# Education_Level                                                                                                                        object
# ...

# %%
# Check for missing values
missing_values = data.isnull().sum()
missing_percentage = (missing_values / len(data)) * 100

print("\nMissing Values Count:")
print(missing_values)

print("\nPercentage of Missing Values:")
print(missing_percentage)
# Out:
# Missing Values Count:
# CLIENTNUM                                                                                                                                0
# Attrition_Flag                                                                                                                           0
# Customer_Age                                                                                                                             0
# Gender                                                                                                                                   0
# Dependent_count                                                                                                                          0
# Education_Level                                                                                                                       1519
# ...

# %%
# List of columns with missing values to be handled
columns_with_missing = ['Education_Level', 'Marital_Status', 'Income_Category']

# Step 1: Show missing values before handling them
print("\n--- Missing Values Before Handling ---\n")
print(data[columns_with_missing].isnull().sum())

# Step 2: Display the unique values and the mode for each column
print("\n--- Mode and Unique Values for Each Column ---\n")
for col in columns_with_missing:
    if data[col].isnull().sum() > 0:  # Only process columns with missing values
        mode_value = data[col].mode()[0]  # Get the mode of the column
        print(f"Column: '{col}'")
        print(f"Unique Values Before Handling: {data[col].unique()}")
        print(f"Mode (most frequent value) Used to Fill Missing Values: {mode_value}\n")
        
        # Fill missing values with the mode
        data[col].fillna(mode_value, inplace=True)

# Step 3: Verify if all missing values are handled
print("\n--- Missing Values After Handling ---\n")
print(data[columns_with_missing].isnull().sum())

# Step 4: Show a few rows to demonstrate how the changes look
print("\n--- Sample Rows After Handling Missing Values ---\n")
print(data[columns_with_missing].head(10))  # Show first 10 rows of the columns
# Out:
# --- Missing Values Before Handling ---
#
# Education_Level    1519
# Marital_Status      749
# Income_Category    1112
# dtype: int64
#
# --- Mode and Unique Values for Each Column ---
#
# Column: 'Education_Level'
# Unique Values Before Handling: ['High School' 'Graduate' 'Uneducated' nan 'College' 'Post-Graduate'
#  'Doctorate']
# Mode (most frequent value) Used to Fill Missing Values: Graduate
#
# Column: 'Marital_Status'
# Unique Values Before Handling: ['Married' 'Single' nan 'Divorced']
# Mode (most frequent value) Used to Fill Missing Values: Married
#
# Column: 'Income_Category'
# Unique Values Before Handling: ['$60K - $80K' 'Less than $40K' '$80K - $120K' '$40K - $60K' '$120K +' nan]
# Mode (most frequent value) Used to Fill Missing Values: Less than $40K
#
#
# --- Missing Values After Handling ---
#
# Education_Level    0
# Marital_Status     0
# Income_Category    0
# dtype: int64
#
# --- Sample Rows After Handling Missing Values ---
#
# ...
